# %%
my_key="BHS1se%2B3loQRJoDAFuG84hXDgqbhriXiPt5esm1EhRrWfqegXJ%2FP17NnaWDnH6F23nDGG8FZ9rMqYaCnr4AJdw%3D%3D"

# %%
url1="http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey="
url2= "LAWD_CD=11110&DEAL_YMD=201512&"

# %%
url = url1 + my_key + url2
print(url)
# Out:
# http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=BHS1se%2B3loQRJoDAFuG84hXDgqbhriXiPt5esm1EhRrWfqegXJ%2FP17NnaWDnH6F23nDGG8FZ9rMqYaCnr4AJdw%3D%3DLAWD_CD=11110&DEAL_YMD=201512&

# %%
import urllib.request
res = urllib.request.urlopen(url)
res

# %% [markdown]
# http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&

# %%
lawd_cd='11110'
deal_ymd='201512'
basicurl='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?'
new_key='s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D'
params='serviceKey=%s&LAWD_CD=%s&DEAL_YMD=%s'%(new_key,lawd_cd,deal_ymd)

url=basicurl+params
print(url)
# Out:
# http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512

# %%
aa='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512'

# %%
http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512url==aa
# Out:
# True

# %% [markdown]
# aa와 url 두 개 문자열 비교해서 틀린 곳 찾기\
# -몇번째에서 틀렸는지?\
# -틀린곳 근처 10개 문자 출력

# %%
for i, check in enumerate (aa):
    if check != url[i]:
        print('find=', i, check)

# %%
print(len(url)); print(len(aa))
# Out:
# 234
# 234

# %%
import requests
lawd_cd ='11110'
deal_ymd = '201512'

my_key_decode = requests.utils.unquote(my_key)
base_url='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey='
req_params={'serviceKey':my_key_decode, 'LAWD_CD':lawd_cd,'DEAL_YMD':deal_ymd,'type':'json'}
r=requests.get(base_url,params=req_params)
print(r.url)
# Out:
# http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=&serviceKey=BHS1se%2B3loQRJoDAFuG84hXDgqbhriXiPt5esm1EhRrWfqegXJ%2FP17NnaWDnH6F23nDGG8FZ9rMqYaCnr4AJdw%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&type=json

# %%
res = urllib.request.urlopen(aa)
res

# %%
xml_str=res.read().decode('utf-8')
xml_str
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>120,000</거래금액><건물면적>395</건물면적><건물주용도>제2종근린생활</건물주용도><건축년도>2001</건축년도><년>2015</년><대지면적>160.64</대지면적><법정동> 효자동</법정동><시군구>종로구</시군구><용도지역>제2종일반주거</용도지역><월>12</월><유형>일반</유형><일>31</일><지역코드>11110</지역코드></item><item><거래금액>483,000</거래금액><건물면적>937</건물면적><건물주용도>제2종근린생활</건물주용도><건축년도>1990</건축년도><년>2015</년><대지면적>503.5</대지면적><법정동> 체부동</법정동><시군구>종로구</시군구><용도지역>제2종일반주거</용도지역><월>12</월><유형>일반</유형><일>15</일><지역코드>11110</지역코드></item><item><거래금액>22,000</거래금액><건물면적>31</건물면적><건물주용도>판매</건물주용도><건축년도>2007</건축년도><년>2015</년><대지면적> </대지면적><법정동> 종로1가</법정동><시군구>종로구</시군구><용도지역>일반상업</용도지역><월>12</월><유형>집합</유형><일>10</일><지역코드>11110</지역코드><층>-1</층></item><item><거래금액>158,000</거래금액><건물면적>276</건물면적><건물주용도>숙박</건물주용도><건축년도>1959</건축년도><년>2015</년><대지면적>72.8</대지면적><법정동> 와룡동</법정동><시군구>종로구</시군구><용도지역>일반상업</용도지역><월>12</월><유형>일반</유형><일>8</일><지역코드>11110</지역코드></ite
# ...

# %%
import xmltodict
import json
json_str=json.dumps(xmltodict.parse(xml_str),indent=4,ensure_ascii=False)
json_object=json.loads(json_str)
json_object
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'거래금액': '120,000',
#       '건물면적': '395',
#       '건물주용도': '제2종근린생활',
#       '건축년도': '2001',
#       '년': '2015',
#       '대지면적': '160.64',
#       '법정동': '효자동',
#       '시군구': '종로구',
#       '용도지역': '제2종일반주거',
#       '월': '12',
#       '유형': '일반',
#       '일': '31',
#       '지역코드': '11110'},
#      {'거래금액': '483,000',
#       '건물면적': '937',
#       '건물주용도': '제2종근린생활',
#       '건축년도': '1990',
#       '년': '2015',
#       '대지면적': '503.5',
#       '법정동': '체부동',
#       '시군구': '종로구',
#       '용도지역': '제2종일반주거',
#       '월': '12',
#       '유형': '일반',
#       '일': '15',
#       '지역코드': '11110'},
#      {'거래금액': '22,000',
#       '건물면적': '31',
#       '건물주용도': '판매',
#       '건축년도': '2007',
#       '년': '2015',
#       '대지면적': None,
#       '법정동': '종로1가',
#       '시군구': '종로구',
#       '용도지역': '일반상업',
#       '월': '12',
#       '유형': '집합',
#       '일': '10',
# ...

# %%
json_object['response']['body']['items']['item']
# Out:
# [{'거래금액': '120,000',
#   '건물면적': '395',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '2001',
#   '년': '2015',
#   '대지면적': '160.64',
#   '법정동': '효자동',
#   '시군구': '종로구',
#   '용도지역': '제2종일반주거',
#   '월': '12',
#   '유형': '일반',
#   '일': '31',
#   '지역코드': '11110'},
#  {'거래금액': '483,000',
#   '건물면적': '937',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '1990',
#   '년': '2015',
#   '대지면적': '503.5',
#   '법정동': '체부동',
#   '시군구': '종로구',
#   '용도지역': '제2종일반주거',
#   '월': '12',
#   '유형': '일반',
#   '일': '15',
#   '지역코드': '11110'},
#  {'거래금액': '22,000',
#   '건물면적': '31',
#   '건물주용도': '판매',
#   '건축년도': '2007',
#   '년': '2015',
#   '대지면적': None,
#   '법정동': '종로1가',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '12',
#   '유형': '집합',
#   '일': '10',
#   '지역코드': '11110',
#   '층': '-1'},
#  {'거래금액': '158,000',
#   '건물면적': '276',
#   '건물주용도': '숙박',
#   '건축년도': '1959',
#   '년': '2015',
#   '대지면적': '72.8',
#   '법정동': '와룡동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '12',
#   '유형': '일반',
#   '일': '8',
#   '지역코드': '11110'},
# ...

# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
df=json_normalize(json_object['response']['body']['items']['item'])
df.head(3)
# Out:
# <ipython-input-150-a6aa3e682f9f>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df=json_normalize(json_object['response']['body']['items']['item'])
#       거래금액 건물면적    건물주용도  건축년도     년    대지면적   법정동  시군구     용도지역   월  유형   일  \
# 0  120,000  395  제2종근린생활  2001  2015  160.64   효자동  종로구  제2종일반주거  12  일반  31
# 1  483,000  937  제2종근린생활  1990  2015   503.5   체부동  종로구  제2종일반주거  12  일반  15
# 2   22,000   31       판매  2007  2015    None  종로1가  종로구     일반상업  12  집합  10
#
#     지역코드    층
# 0  11110  NaN
# 1  11110  NaN
# 2  11110   -1

# %%
import json

# %%
dir(json)
# Out:
# ['JSONDecodeError',
#  'JSONDecoder',
#  'JSONEncoder',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_default_decoder',
#  '_default_encoder',
#  'codecs',
#  'decoder',
#  'detect_encoding',
#  'dump',
#  'dumps',
#  'encoder',
#  'load',
#  'loads',
#  'scanner']

# %%
data=['foo',{'bar':('baz',None,1.0,2)}]
data
# Out:
# ['foo', {'bar': ('baz', None, 1.0, 2)}]

# %%
type(data)
# Out:
# list

# %%
import json
dict_data={'이름':'김인공','나이':29,'거주지':'서울','신체정보':{'키':165.4,'몸무게':'65.2'}
          ,'취미':['컴퓨터','파이썬','데이터덕후']}
dict_data
# Out:
# {'이름': '김인공',
#  '나이': 29,
#  '거주지': '서울',
#  '신체정보': {'키': 165.4, '몸무게': '65.2'},
#  '취미': ['컴퓨터', '파이썬', '데이터덕후']}

# %%
### dict to JSON
json_data = json.dumps(dict_data,indent=3, sort_keys=True, ensure_ascii=False)
type(json_data)
# Out:
# str

# %%
json_data
# Out:
# '{\n   "거주지": "서울",\n   "나이": 29,\n   "신체정보": {\n      "몸무게": "65.2",\n      "키": 165.4\n   },\n   "이름": "김인공",\n   "취미": [\n      "컴퓨터",\n      "파이썬",\n      "데이터덕후"\n   ]\n}'

# %%
json_dict=json.loads(json_data)
type(json_dict)
# Out:
# dict

# %%
json_dict['신체정보']['키']
# Out:
# 165.4
