# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
tt=pd.read_csv('C:\wonyoung/titanic.csv')
#1
tt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#2 데이터크기 구하기
print(tt.shape)
# Out:
# (891, 12)

# %%
#3 결측치가 있는 컬럼
pd.isnull(tt).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#4 Pclass 내 종류 갯수
tt['Pclass'].astype('category')
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: category
# Categories (3, int64): [1, 2, 3]

# %%
tt['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#5     #남자/여자 각각 평균 나이
average=tt[['Sex','Age']].groupby('Sex')
average.mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
#6     #Fare의 최댓값, 최솟값
faremin=tt['Fare'].min()
faremax=tt['Fare'].max()
print(faremin)
print(faremax)
# Out:
# 0.0
# 512.3292

# %%
# 남녀별 Fare의 최댓값 최솟값
print(tt[['Sex','Fare']].groupby('Sex').max())
print(tt[['Sex','Fare']].groupby('Sex').min())
# Out:
#             Fare
# Sex
# female  512.3292
# male    512.3292
#         Fare
# Sex
# female  6.75
# male    0.00
